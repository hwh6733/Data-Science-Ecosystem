# %% [markdown]
# # My solution for the peer assignment for the IBM Data Science course

# %% [markdown]
# I am civil engineer from Freiburg in Germany and I work in the energy supply business with frocus on infrastructur. I do this course to get some fundamental understanding on data science.This is my solution to the task of week 6.

# %% [markdown]
# ## List of some of the languages used in data science:

# %% [markdown]
# 1. Python
# 2. R
# 3. SQL
# 4. C++
# 5. Java
# etc.

# %% [markdown]
# ## List of some of the liabaries used in data science:

# %% [markdown]
# 1. Tensorflow
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn
# 5. Plotly
# 6. Scikit-Learn
# 7. Pytorch
# etc.

# %% [markdown]
# ## A table of some of the tools used in data science:

# %% [markdown]
# |data science tools|
# |------------------|
# | SAS|
# |TensorFlow|
# |Apache Hadoop|

# %% [markdown]
# ## A few examples of evaluation aritmetic expressions in python:
# Multiply, Add, convert units, etc.

# %% [markdown]
# ### This is an arithmetic expression to multiply and then add integers:

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ### This is a expression to convert 180 minutes into hours:

# %%
180/60
# Out:
# 3.0

# %% [markdown]
# ## List of the objectives, as set above:

# %% [markdown]
# * List common languages
# * List common liabaries
# * Create table of tools
# * List examples of aritmetic expressions

# %% [markdown]
# ## Author:
# Heinz-Werner Hölscher
